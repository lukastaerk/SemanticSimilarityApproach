# %%
# %load_ext autoreload
# %autoreload 2
from evaluation import WordSimEvaluation
wordEval = WordSimEvaluation()
metrics = ["path", "wpath_graph", "res", "lin", "jcn"]

# %%
wordEval.evaluate_datasets_wpath_k("wpath_graph", wordEval.dataset_names, display_table=True, ic_func="ic_graph_global", relatedness=True)
# Out:
#        noun_rg  noun_mc  noun_ws353  noun_ws353-sim  noun_simlex
# k=0.1    0.670    0.768       0.315           0.524        0.325
# k=0.2    0.721    0.827       0.330           0.553        0.339
# k=0.3    0.730    0.841       0.343           0.593        0.356
# k=0.4    0.743    0.830       0.353           0.611        0.358
# k=0.5    0.781    0.844       0.361           0.617        0.370
# k=0.6    0.796    0.862       0.363           0.627        0.382
# k=0.7    0.799    0.859       0.367           0.636        0.393
# k=0.8    0.804    0.876       0.365           0.647        0.405
# k=0.9    0.811    0.905       0.361           0.663        0.425
# k=1.0    0.805    0.908       0.335           0.641        0.419

# %%
range_k = [k/100 for k in range(80, 101, 2)]
print(range_k)
wordEval.evaluate_datasets_wpath_k("wpath_graph", 
                                   wordEval.dataset_names, display_table=True, 
                                   ic_func="ic_graph_global", 
                                   relatedness=True, range_k=range_k)
# Out:
# [0.8, 0.82, 0.84, 0.86, 0.88, 0.9, 0.92, 0.94, 0.96, 0.98, 1.0]
# done calculation all shortest distance
# done calculation all shortest distance
# done calculation all shortest distance
# done calculation all shortest distance
#         noun_rg  noun_mc  noun_ws353  noun_ws353-sim  noun_simlex
# k=0.8     0.804    0.876       0.365           0.647        0.405
# k=0.82    0.810    0.884       0.364           0.648        0.410
# k=0.84    0.806    0.890       0.362           0.653        0.411
# k=0.86    0.808    0.895       0.362           0.657        0.415
# k=0.88    0.810    0.895       0.360           0.661        0.423
# k=0.9     0.811    0.905       0.361           0.663        0.425
# k=0.92    0.812    0.906       0.360           0.670        0.426
# k=0.94    0.815    0.906       0.359           0.665        0.426
# k=0.96    0.818    0.906       0.353           0.663        0.425
# k=0.98    0.819    0.905       0.350           0.662        0.418
# ...

# %%
wordEval.evaluate_datasets_metrics(metrics, wordEval.dataset_names, ic_func="ic_graph_global", k=0.9, relatedness=True, display_table=True)
# Out:
# done calculation all shortest distance
# done calculation all shortest distance
# done calculation all shortest distance
# done calculation all shortest distance
#              noun_rg  noun_mc  noun_ws353  noun_ws353-sim  noun_simlex
# path           0.805    0.908       0.326           0.645        0.418
# wpath_graph    0.811    0.905       0.350           0.671        0.414
# res            0.739    0.824       0.374           0.525        0.294
# lin            0.791    0.871       0.388           0.576        0.342
# jcn            0.803    0.873       0.287           0.537        0.360

# %%
wordEval.evaluate_datasets_metrics(metrics, wordEval.dataset_names, ic_func="ic_graph_global", k=0.9, relatedness=True, display_table=True)
# Out:
#              noun_rg  noun_mc  noun_ws353  noun_ws353-sim  noun_simlex
# path           0.805    0.908       0.335           0.641        0.419
# wpath_graph    0.811    0.905       0.361           0.663        0.425
# res            0.739    0.823       0.371           0.525        0.293
# lin            0.790    0.871       0.390           0.586        0.358
# jcn            0.803    0.873       0.328           0.540        0.367

# %%
wordEval.evaluate_datasets_metrics(metrics, wordEval.dataset_names, ic_func="ic_graph_global",lcs_pref_value="freq1", k=0.9, relatedness=True, display_table=True)
# Out:
# done calculation all shortest distance for: freq1
# done calculation all shortest distance for: freq1
# done calculation all shortest distance for: freq1
# done calculation all shortest distance for: freq1
# done calculation all shortest distance for: freq1
#              noun_rg  noun_mc  noun_ws353  noun_ws353-sim  noun_simlex
# path           0.794    0.901       0.362           0.605        0.461
# wpath_graph    0.781    0.876       0.362           0.648        0.425
# res            0.591    0.702       0.283           0.481        0.184
# lin            0.710    0.809       0.338           0.587        0.285
# jcn            0.752    0.834       0.314           0.584        0.319

# %%
wordEval.evaluate_metric("wpath_graph", "noun_rg", ic_func="ic_graph_global", k=0.9, relatedness=True, save_results=True)
# Out:
# done calculation all shortest distance
# 0.811

# %%
import pandas as pd 
csv = pd.read_csv("dataset/wordsim/results-csv/noun_rg_wpath_graph_shortest_path_0.9.csv")
csv
# Out:
#     Unnamed: 0     wordone    wordtwo  mean   sim                        LCS
# 0            0         gem      jewel  3.94  4.00                   gemstone
# 1            1      midday       noon  3.94  4.00                       noon
# 2            2  automobile        car  3.92  4.00                        car
# 3            3    cemetery  graveyard  3.88  4.00                   cemetery
# 4            4     cushion     pillow  3.84  3.21                    cushion
# 5            5         boy        lad  3.82  4.00                        boy
# 6            6        cock    rooster  3.68  4.00                    rooster
# 7            7   implement       tool  3.66  4.00                       tool
# 8            8      forest   woodland  3.65  2.67                     forest
# 9            9       coast      shore  3.60  4.00                       bank
# 10          10   autograph  signature  3.59  3.28                  signature
# ...

# %%
from similarity import ConceptSimilarity
from analytics import DiGraph, DAC
from dataset import Dataset
ds = Dataset()
dataset_name = "noun_mc"
concepts, word_pairs, get_ids_from_noun = ds.transform_dataset(dataset_name)

MCT = DAC(concepts=concepts, dataset=dataset_name, relatedness=True)
CS = ConceptSimilarity(MCT)
#sorted(MCT.graph.in_edges("Q19361238",data=True), key=lambda x: MCT.graph.in_degree(x))

# %%
item = "Q19361238"
#item = "Q36809769"
gemstone = "Q83437"
noon = "Q168182"
string = "Q184754"
geoObj = "Q618123"
person = "Q5"
car = "Q1420"
CS.ic_graph_global(geoObj)#, CS.res(noon,string,ic_func="ic_graph_global")
# Out:
# 1.6149954977227416

# %%
sorted(list(["Q168182","Q83437","Q5", "Q618123"]),key=lambda x: x[1])
# Out:
# ['Q168182', 'Q5', 'Q618123', 'Q83437']

# %%
MCT.graph.nodes["Q5"]
# Out:
# {'value': 'human', 'freq1': 6535964}
